# %% [markdown]
# # Removing duplicates from SwiftDS-Stripe82
#
# We have produced a catalog using the Swift DeepSky pipeline, where all Swift observations inside the Stripe82 were used.
#
# Let's now filter the duplicated entries and have a look on it.

# %%
# swift_file = 'table_countrates_stripe82_all_swift_pointings.csv'

swift_file = 'swift_deepsky/table_countrates_detections_stripe82.csv'

# %%
import pandas as pd
pd.set_option('display.max_rows',10)

df = pd.read_csv(swift_file, sep=';')

# %%
df.head()
# Out:
#              RA            DEC  countrates_0.3-10keV(ph.s-1)  \
# 0  00:56:24.480  -01:16:38.317                      0.005645
# 1  00:56:19.136  -01:14:58.198                      0.004449
# 2  00:56:23.004  -01:13:39.516                      0.003901
# 3  00:56:16.418  -01:14:05.418                      0.005795
# 4  00:56:16.922  -01:13:16.401                      0.005224
#
#    countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# 0                              0.0015            4572.8
# 1                              0.0014            4684.2
# 2                              0.0014            4649.6
# 3                              0.0016            4642.0
# 4                              0.0015            4587.3
#
#    countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# 0                     0.000868                           0.000600
# 1                     0.000494                           0.000485
# 2                     0.000867                           0.000679
# 3                     0.000446                           0.000460
# 4                     0.002177                           0.000937
#
#    upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# 0                        -999.0                   0.003040
# 1                        -999.0                   0.001977
# 2                        -999.0                   0.001301
# 3                        -999.0                   0.002674
# 4                        -999.0                   0.001306
#
#    countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# 0                         0.001125                      -999.0
# 1                         0.000959                      -999.0
# 2                         0.000840                      -999.0
# 3                         0.001100                      -999.0
# 4                         0.000741                      -999.0
#
#    countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# 0                    0.001737                          0.000853
# 1                    0.001977                          0.000959
# 2                    0.001734                          0.000969
# 3                    0.002674                          0.001100
# 4                    0.001741                          0.000853
#
#    upper_limit_2-10keV(ph.s-1)
# 0                       -999.0
# 1                       -999.0
# 2                       -999.0
# 3                       -999.0
# 4                       -999.0

# %%
from astropy.coordinates import SkyCoord
from astropy import units

swift_coords = SkyCoord(df.RA, df.DEC, unit=(units.hourangle,units.degree))
df['RA'] = swift_coords.ra.deg
df['DEC'] = swift_coords.dec.deg
df.head()
# Out:
#           RA       DEC  countrates_0.3-10keV(ph.s-1)  \
# 0  14.102000 -1.277310                      0.005645
# 1  14.079733 -1.249499                      0.004449
# 2  14.095850 -1.227643                      0.003901
# 3  14.068408 -1.234838                      0.005795
# 4  14.070508 -1.221223                      0.005224
#
#    countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# 0                              0.0015            4572.8
# 1                              0.0014            4684.2
# 2                              0.0014            4649.6
# 3                              0.0016            4642.0
# 4                              0.0015            4587.3
#
#    countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# 0                     0.000868                           0.000600
# 1                     0.000494                           0.000485
# 2                     0.000867                           0.000679
# 3                     0.000446                           0.000460
# 4                     0.002177                           0.000937
#
#    upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# 0                        -999.0                   0.003040
# 1                        -999.0                   0.001977
# 2                        -999.0                   0.001301
# 3                        -999.0                   0.002674
# 4                        -999.0                   0.001306
#
#    countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# 0                         0.001125                      -999.0
# 1                         0.000959                      -999.0
# 2                         0.000840                      -999.0
# 3                         0.001100                      -999.0
# 4                         0.000741                      -999.0
#
#    countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# 0                    0.001737                          0.000853
# 1                    0.001977                          0.000959
# 2                    0.001734                          0.000969
# 3                    0.002674                          0.001100
# 4                    0.001741                          0.000853
#
#    upper_limit_2-10keV(ph.s-1)
# 0                       -999.0
# 1                       -999.0
# 2                       -999.0
# 3                       -999.0
# 4                       -999.0

# %% [markdown]
# ## xmatch using 'gc-filtering' algorithm
#
# Let's remove the duplicates by matching the catalog with itself and the nearby matches should be removed according to their SNR.

# %% [markdown]
# ### SNR column
#
# Let's define the objects' overall SNR estimate to be the ratio between columns `countrates_0.3-10keV(ph.s-1)` and `countrates_error_0.3-10keV(ph.s-1)`, which are the countrate and error associated to the full band emission.

# %%
df['snr'] = df['countrates_0.3-10keV(ph.s-1)']/df['countrates_error_0.3-10keV(ph.s-1)']

# %% [markdown]
# **xmatch** needs columns 'ra','dec','id' to be defined. As well as the search radius.

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'OBJID'}, inplace=True)

# %%
df.head()
# Out:
#    OBJID         RA       DEC  countrates_0.3-10keV(ph.s-1)  \
# 0      0  14.102000 -1.277310                      0.005645
# 1      1  14.079733 -1.249499                      0.004449
# 2      2  14.095850 -1.227643                      0.003901
# 3      3  14.068408 -1.234838                      0.005795
# 4      4  14.070508 -1.221223                      0.005224
#
#    countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# 0                              0.0015            4572.8
# 1                              0.0014            4684.2
# 2                              0.0014            4649.6
# 3                              0.0016            4642.0
# 4                              0.0015            4587.3
#
#    countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# 0                     0.000868                           0.000600
# 1                     0.000494                           0.000485
# 2                     0.000867                           0.000679
# 3                     0.000446                           0.000460
# 4                     0.002177                           0.000937
#
#    upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# 0                        -999.0                   0.003040
# 1                        -999.0                   0.001977
# 2                        -999.0                   0.001301
# 3                        -999.0                   0.002674
# 4                        -999.0                   0.001306
#
#    countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# 0                         0.001125                      -999.0
# 1                         0.000959                      -999.0
# 2                         0.000840                      -999.0
# 3                         0.001100                      -999.0
# 4                         0.000741                      -999.0
#
#    countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# 0                    0.001737                          0.000853
# 1                    0.001977                          0.000959
# 2                    0.001734                          0.000969
# 3                    0.002674                          0.001100
# 4                    0.001741                          0.000853
#
#    upper_limit_2-10keV(ph.s-1)       snr
# 0                       -999.0  3.763333
# 1                       -999.0  3.177857
# 2                       -999.0  2.786429
# 3                       -999.0  3.621875
# 4                       -999.0  3.482667

# %%
from astropy.coordinates import Angle
radius = Angle(5, 'arcsec')

cols = {'ra':'RA', 'dec':'DEC', 'id':'OBJID'}

# %%
from xmatch import xmatch

help(xmatch)
# Out:
# Help on function xmatch in module xmatch._xmatchi:
#
# xmatch(catalog_A, catalog_B, columns_A=None, columns_B=None, radius=None, minimal=True, method='gc', snr_column=None)
#     Returns the cross-matched catalog of same size as 'catalog_A' (left join)
#
#     Output (table) provides the input positional columns as well as the
#     measurements used during the matching process, in particular the separation
#     distances between matching pairs as well as the serialized list of (eventual)
#     duplicated matchings. The (physical) unit for sources separation distances is
#     *arc seconds*.
#
#     'snr_colunm' is used to filter duplicates. Say you want to remove duplicated
#     matches (matches with same target but mulitiple counterparts) based on a
#     a signal-to-noise (snr) measurement for each source, the 'snr_column' column
#     name is to be used.
#
#     Input:
#      - catalog_{A,B} : ~pandas.DataFrame
#         DFs containing (at least) the columns 'ra','dec','id'
#
#      - columns_{A,B} : dict mapping 'ra','dec','id' columns
#         In case catalog(s) have different column names for 'ra','dec','id';
#         e.g, {'ra':'RA', 'dec':'Dec', 'id':'ObjID'}
#
#      - radius: astropy' angle quantity
#         Define the region size around to search for counterparts (gc only)
#
#      - method: string
#         Options are 'nn' or 'gc' (default)
#
#      - separation_unit: string
#         Unit to use in output catalog for the separation between matches;
#         Options are 'arcsec', 'arcmin', 'degree'
#
#      - minimal : bool
#         If True, output catalog contains only the positional columns
#
#      - snr_column : string
#         Name of the column to use as disambiguation feature when filtering duplicates
#
#     Output:
#      - matched_catalog : ~pandas.DataFrame

# %%
xcat = xmatch(df, df, columns_A=cols, columns_B=cols, radius=radius, snr_column='snr')

# %%
print(len(xcat))
xcat.head(20)
# Out:
# 2764
#              A                           B                         AB  \
#             RA       DEC OBJID          RA       DEC OBJID        snr
# 0    14.102000 -1.277310     0   14.102000 -1.277310   0.0   3.763333
# 1    14.079733 -1.249499     1   14.079733 -1.249499   1.0   3.177857
# 2    14.095850 -1.227643     2   14.095850 -1.227643   2.0   2.786429
# 3    14.068408 -1.234838     3   14.068408 -1.234838   3.0   3.621875
# 4    14.070508 -1.221223     4   14.070508 -1.221223   4.0   3.482667
# ..         ...       ...   ...         ...       ...   ...        ...
# 15  310.824271 -0.723092    15  310.824271 -0.723092  15.0  46.750000
# 16  310.812667 -0.677192    16  310.812667 -0.677192  16.0  12.917949
# 17  310.778537 -0.707921    17  310.778537 -0.707921  17.0   3.338333
# 18  310.931058 -0.761124    18  310.931058 -0.761124  18.0   3.284375
# 19  310.770017 -0.634637    19  310.770017 -0.634637  19.0   6.152000
#
#
#    duplicates           snrs
# 0        3309  3.76333333333
# 1        3310  3.17785714286
# 2        3311  2.78642857143
# 3        3312       3.621875
# 4        3313  3.48266666667
# ..        ...            ...
# 15       1250          46.75
# 16       1251  12.9179487179
# 17       1252  3.33833333333
# 18       1253       3.284375
# 19       1254          6.152
#
# [20 rows x 9 columns]

# %%
pcat = df.set_index('OBJID').loc[xcat[('B','OBJID')]]

# %%
print(len(pcat))
pcat.head(20)
# Out:
# 2764
#                RA       DEC  countrates_0.3-10keV(ph.s-1)  \
# OBJID
# 0.0     14.102000 -1.277310                      0.005645
# 1.0     14.079733 -1.249499                      0.004449
# 2.0     14.095850 -1.227643                      0.003901
# 3.0     14.068408 -1.234838                      0.005795
# 4.0     14.070508 -1.221223                      0.005224
# ...           ...       ...                           ...
# 15.0   310.824271 -0.723092                      0.056100
# 16.0   310.812667 -0.677192                      0.005038
# 17.0   310.778537 -0.707921                      0.000601
# 18.0   310.931058 -0.761124                      0.000526
# 19.0   310.770017 -0.634637                      0.001538
#
#        countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# OBJID
# 0.0                               0.00150            4572.8
# 1.0                               0.00140            4684.2
# 2.0                               0.00140            4649.6
# 3.0                               0.00160            4642.0
# 4.0                               0.00150            4587.3
# ...                                   ...               ...
# 15.0                              0.00120           44772.7
# 16.0                              0.00039           45446.9
# 17.0                              0.00018           40150.7
# 18.0                              0.00016           45644.2
# 19.0                              0.00025           42129.6
#
#        countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# OBJID
# 0.0                       0.000868                           0.000600
# 1.0                       0.000494                           0.000485
# 2.0                       0.000867                           0.000679
# 3.0                       0.000446                           0.000460
# 4.0                       0.002177                           0.000937
# ...                            ...                                ...
# 15.0                      0.014080                           0.000590
# 16.0                      0.001142                           0.000183
# 17.0                      0.000234                           0.000115
# 18.0                      0.000143                           0.000084
# 19.0                      0.000452                           0.000138
#
#        upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# OBJID
# 0.0                          -999.0                   0.003040
# 1.0                          -999.0                   0.001977
# 2.0                          -999.0                   0.001301
# 3.0                          -999.0                   0.002674
# 4.0                          -999.0                   0.001306
# ...                             ...                        ...
# 15.0                         -999.0                   0.024650
# 16.0                         -999.0                   0.002116
# 17.0                         -999.0                   0.000200
# 18.0                         -999.0                   0.000191
# 19.0                         -999.0                   0.000588
#
#        countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# OBJID
# 0.0                           0.001125                      -999.0
# 1.0                           0.000959                      -999.0
# 2.0                           0.000840                      -999.0
# 3.0                           0.001100                      -999.0
# 4.0                           0.000741                      -999.0
# ...                                ...                         ...
# 15.0                          0.000780                      -999.0
# 16.0                          0.000249                      -999.0
# 17.0                          0.000106                      -999.0
# 18.0                          0.000099                      -999.0
# 19.0                          0.000156                      -999.0
#
#        countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# OBJID
# 0.0                      0.001737                          0.000853
# 1.0                      0.001977                          0.000959
# 2.0                      0.001734                          0.000969
# 3.0                      0.002674                          0.001100
# 4.0                      0.001741                          0.000853
# ...                           ...                               ...
# 15.0                     0.017370                          0.000660
# 16.0                     0.001780                          0.000232
# 17.0                     0.000167                          0.000098
# 18.0                     0.000191                          0.000099
# 19.0                     0.000498                          0.000144
#
#        upper_limit_2-10keV(ph.s-1)        snr
# OBJID
# 0.0                         -999.0   3.763333
# 1.0                         -999.0   3.177857
# 2.0                         -999.0   2.786429
# 3.0                         -999.0   3.621875
# 4.0                         -999.0   3.482667
# ...                            ...        ...
# 15.0                        -999.0  46.750000
# 16.0                        -999.0  12.917949
# 17.0                        -999.0   3.338333
# 18.0                        -999.0   3.284375
# 19.0                        -999.0   6.152000
#
# [20 rows x 15 columns]

# %%
pcat.reset_index(inplace=True)
del pcat['snr']

# %%
pcat.sample(10)
# Out:
#        OBJID          RA       DEC  countrates_0.3-10keV(ph.s-1)  \
# 780   6327.0    6.824771 -1.072169                      0.000782
# 1814  2892.0  329.110746 -0.460593                      0.001321
# 431    444.0   17.572867 -0.432856                      0.002108
# 2284  4253.0    9.988129 -0.212513                      0.003248
# 132    132.0  356.019229  0.381615                      0.001175
# 32      32.0  310.821458 -0.872621                      0.000602
# 2527  5127.0   31.726654  0.324099                      0.000516
# 1063  1363.0   31.621029 -0.368616                      0.000721
# 1338  1704.0   13.165771 -0.644142                      0.173000
# 271   4384.0   16.809458 -0.833394                      0.003152
#
#       countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# 780                              0.00017           38206.7
# 1814                             0.00038           16563.1
# 431                              0.00051           10717.7
# 2284                             0.00120            3852.7
# 132                              0.00050            7571.1
# 32                               0.00018           44469.7
# 2527                             0.00011           78559.2
# 1063                             0.00023           23601.4
# 1338                             0.00940            2295.9
# 271                              0.00120            3203.1
#
#       countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# 780                      0.000391                           0.000122
# 1814                     0.000377                           0.000205
# 431                      0.001265                           0.000392
# 2284                     0.003248                           0.001200
# 132                      0.001175                           0.000500
# 32                       0.000547                           0.000164
# 2527                     0.000352                           0.000091
# 1063                     0.000160                           0.000112
# 1338                     0.048000                           0.004994
# 271                      0.001576                           0.000867
#
#       upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# 780                         -999.0                   0.000313
# 1814                        -999.0                   0.000755
# 431                         -999.0                   0.000422
# 2284                        -999.0                   0.002166
# 132                         -999.0                   0.000392
# 32                          -999.0                   0.000216
# 2527                        -999.0                   0.000141
# 1063                        -999.0                   0.000240
# 1338                        -999.0                   0.074270
# 271                         -999.0                   0.000788
#
#       countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# 780                          0.000109                 -999.000000
# 1814                         0.000289                 -999.000000
# 431                          0.000228                 -999.000000
# 2284                        -1.199000                    0.004294
# 132                         -0.499500                    0.001108
# 32                          -0.179800                    0.000362
# 2527                         0.000059                 -999.000000
# 1063                         0.000131                 -999.000000
# 1338                         0.006463                 -999.000000
# 271                          0.000613                 -999.000000
#
#       countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# 780                     0.000078                          0.000054
# 1814                    0.000189                          0.000144
# 431                     0.000422                          0.000228
# 2284                    0.000361                         -1.199000
# 132                     0.000392                         -0.499500
# 32                      0.000055                          0.000053
# 2527                    0.000023                          0.000024
# 1063                    0.000321                          0.000155
# 1338                    0.050710                          0.005111
# 271                     0.000788                          0.000613
#
#       upper_limit_2-10keV(ph.s-1)
# 780                   -999.000000
# 1814                  -999.000000
# 431                   -999.000000
# 2284                     0.004294
# 132                      0.001108
# 32                    -999.000000
# 2527                  -999.000000
# 1063                  -999.000000
# 1338                  -999.000000
# 271                   -999.000000

# %%
pcat.describe()
# Out:
#              OBJID           RA          DEC  countrates_0.3-10keV(ph.s-1)  \
# count  2764.000000  2764.000000  2764.000000                   2764.000000
# mean   2597.801013   126.249303    -0.106153                      0.010130
# std    1798.401101   139.864692     0.787670                      0.090519
# min       0.000000     0.049904    -1.639452                      0.000119
# 25%    1135.750000    29.536324    -0.791660                      0.000854
# 50%    2297.500000    44.151856    -0.159245                      0.001705
# 75%    3978.250000   320.813523     0.516338                      0.003709
# max    6877.000000   359.917396     1.606157                      2.716000
#
#        countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# count                         2764.000000       2764.000000
# mean                             0.000803      35032.097323
# std                              0.001358      49183.157865
# min                              0.000036        387.500000
# 25%                              0.000190       7126.325000
# 50%                              0.000430      14459.750000
# 75%                              0.000830      40978.450000
# max                              0.019000     295994.000000
#
#        countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# count                  2764.000000                        2764.000000
# mean                      0.004325                          -0.057754
# std                       0.037844                           0.311044
# min                       0.000000                          -5.195000
# 25%                       0.000219                           0.000082
# 50%                       0.000550                           0.000210
# 75%                       0.001406                           0.000469
# max                       1.091000                           0.014000
#
#        upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# count                   2764.000000                2764.000000
# mean                    -933.772828                   0.003467
# std                      249.663021                   0.030600
# min                    -2530.000000                   0.000000
# 25%                     -999.000000                   0.000246
# 50%                     -999.000000                   0.000561
# 75%                     -999.000000                   0.001337
# max                        0.082480                   0.911400
#
#        countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# count                      2764.000000                 2764.000000
# mean                         -0.118090                 -926.543975
# std                           0.780844                  261.840428
# min                         -13.990000                -2530.000000
# 25%                           0.000082                 -999.000000
# 50%                           0.000210                 -999.000000
# 75%                           0.000444                 -999.000000
# max                           0.012290                    0.117300
#
#        countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# count                 2764.000000                       2764.000000
# mean                     0.002740                         -0.165761
# std                      0.025492                          0.862769
# min                      0.000000                        -13.990000
# 25%                      0.000223                          0.000071
# 50%                      0.000499                          0.000181
# 75%                      0.001110                          0.000385
# max                      0.944600                          0.007600
#
#        upper_limit_2-10keV(ph.s-1)
# count                  2764.000000
# mean                   -897.990529
# std                     303.547454
# min                   -2530.000000
# 25%                    -999.000000
# 50%                    -999.000000
# 75%                    -999.000000
# max                       0.136400

# %% [markdown]
# ## Save the catalog

# %%
# pcat.to_csv('swiftdeepsky_stripe82_countrates.csv')

# %% [markdown]
# ## Plot: countrates .vs. exposure-time

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="70bbbb21-1628-426e-9db2-b1664d66a2ad">Loading BokehJS ...</span>
#     </div>

# %%
import numpy as np

p = figure(y_axis_type="log", x_axis_type="log")

p.circle(df['exposure_time(s)'], df['countrates_0.3-10keV(ph.s-1)'])

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1d959497-898d-4ed6-9a40-3b4a5feccece"></div>
# </div>

# %% [markdown]
# ## Plot: exposure-time

# %%
# %matplotlib inline

df['exposure_time(s)'].hist()

# %% [markdown]
# ## Plot: countrates

# %%
import seaborn as sns

ax = sns.distplot(df['countrates_0.3-10keV(ph.s-1)'], kde=False)
ax.set_yscale('log')

# %%
pileup = sum(df['countrates_0.3-10keV(ph.s-1)'] > 0.5)
print('Number of pile-ups: ', pileup)
# Out:
# Number of pile-ups:  24

# %% [markdown]
# Pile-up is when two photons arrive at the same CCD frame and the instrument reads that out as a single very energetic photon.
#
# A countrate value above $0.5$ should raise an eyebrow as pile-up is probably in place.
# * http://www.swift.ac.uk/analysis/xrt/pileup.php
# * https://arxiv.org/abs/astro-ph/0701815
#
# Potencially piled-up sources -- 24 in total -- are being removed from our sample.

# %%
idx_pu = df['countrates_0.3-10keV(ph.s-1)'] > 0.5
df = df.loc[~idx_pu]

df.describe()
# Out:
#              OBJID           RA          DEC  countrates_0.3-10keV(ph.s-1)  \
# count  6881.000000  6881.000000  6881.000000                   6881.000000
# mean   3451.511844   116.199982    -0.199829                      0.005260
# std    1992.896083   133.325342     0.787391                      0.023220
# min       0.000000     0.049904    -1.639452                      0.000119
# 25%    1726.000000    31.174004    -0.862422                      0.000663
# 50%    3451.000000    45.192129    -0.274189                      0.001440
# 75%    5177.000000   310.038367     0.404649                      0.003023
# max    6904.000000   359.917396     1.606157                      0.439200
#
#        countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# count                         6881.000000       6881.000000
# mean                             0.000600      46627.991309
# std                              0.000972      55920.729694
# min                              0.000036        387.500000
# 25%                              0.000140       9269.400000
# 50%                              0.000320      20971.100000
# 75%                              0.000670      67908.600000
# max                              0.014000     295994.000000
#
#        countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# count                  6881.000000                        6881.000000
# mean                      0.002129                          -0.044531
# std                       0.010539                           0.259209
# min                       0.000000                          -5.195000
# 25%                       0.000168                           0.000059
# 50%                       0.000429                           0.000149
# 75%                       0.001088                           0.000359
# max                       0.207800                           0.014000
#
#        upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# count                   6881.000000                6881.000000
# mean                    -941.807349                   0.001890
# std                      234.517637                   0.008659
# min                    -2530.000000                   0.000000
# 25%                     -999.000000                   0.000200
# 50%                     -999.000000                   0.000465
# 75%                     -999.000000                   0.001102
# max                        0.082480                   0.226300
#
#        countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# count                      6881.000000                 6881.000000
# mean                         -0.066664                 -948.050140
# std                           0.529446                  222.342817
# min                         -13.990000                -2530.000000
# 25%                           0.000066                 -999.000000
# 50%                           0.000159                 -999.000000
# 75%                           0.000367                 -999.000000
# max                           0.008000                    0.117300
#
#        countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# count                 6881.000000                       6881.000000
# mean                     0.001480                         -0.101393
# std                      0.006046                          0.605715
# min                      0.000000                        -13.990000
# 25%                      0.000188                          0.000063
# 50%                      0.000410                          0.000138
# 75%                      0.000926                          0.000313
# max                      0.143500                          0.006848
#
#        upper_limit_2-10keV(ph.s-1)          snr
# count                  6881.000000  6881.000000
# mean                   -924.385227     6.076438
# std                     264.781586     8.048288
# min                   -2530.000000     2.040541
# 25%                    -999.000000     3.287097
# 50%                    -999.000000     4.280000
# 75%                    -999.000000     6.188235
# max                       0.091520   189.384615

# %% [markdown]
# ## Plot: Sky distribution

# %%
from astropy import units
import astropy.coordinates as coord

ra = coord.Angle(df['RA'], units.degree)
ra = ra.wrap_at(180 * units.degree)
dec = coord.Angle(df['DEC'], units.degree)

# %%
from matplotlib import pyplot as plt

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111, projection="hammer")

ax.scatter(ra.radian, dec.radian)

# ax.set_xticklabels(['14h','16h','18h','20h','22h','0h','2h','4h','6h','8h','10h'])
ax.grid(True)

# %%
from bokeh.plotting import figure, show

p = figure(x_range=(-70,70), y_range=(-2,2))
p.grid.visible = True

p.circle(x=ra.degree, y=dec.degree)

show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c4d05d2f-7f3b-4605-a8da-35c59dc22447"></div>
# </div>
