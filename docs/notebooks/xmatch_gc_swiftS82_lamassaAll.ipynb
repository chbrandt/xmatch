# %% [markdown]
# # Cross-matching Swift and LaMassa
#
# We have produced a catalog from the Swift DeepSky pipeline, where LaMassa's Chandra pointings were used to select the Swift observations.
# Now we want to take the results from such processing and correlate with LaMassa's.

# %%
import pandas as pd
pd.set_option("display.max_rows",10)

# %%
swift_file = 'swift_deepsky_s82_unique.csv'
chandra_file = 'lamassa/chandra.dat'
xmm10_file = 'lamassa/xmmao10.dat'
xmm13_file = 'lamassa/xmmao13.dat'

# %%
from astropy.table import Table

lm_chandra = Table.read(chandra_file, format='cds', readme='lamassa/ReadMe')
lm_xmm10 = Table.read(xmm10_file, format='cds', readme='lamassa/ReadMe')
lm_xmm13 = Table.read(xmm13_file, format='cds', readme='lamassa/ReadMe')

# %%
# print(len(lm_chandra.colnames))
# print(lm_chandra.colnames)

# %%
# print(len(lm_xmm10.colnames))
# print(lm_xmm10.colnames)

# %%
# print(len(lm_xmm13.colnames))
# print(lm_xmm13.colnames)

# %%
# import pandas
# df = pandas.concat([lm_chandra.to_pandas(),
#                     lm_xmm10.to_pandas(),
#                     lm_xmm13.to_pandas()])
# df.sample(20)

# %%
import pandas as pd

swift = pd.read_csv(swift_file)

# %%
lm_chandra
# Out:
# <Table masked=True length=1146>
#  MSID  ObsID  RAdeg   DEdeg   e_Pos  ...  e_F500 XMMAO10CP XMMAO13CP CPCoord
#                deg     deg    arcsec ...   mJy
# int64  int64 float64 float64 float64 ... float64    str5      str4    int64
# ------ ----- ------- ------- ------- ... ------- --------- --------- -------
#  15288  7750  29.212   -0.76     8.9 ...      --        --        --       0
#  15292  7750   29.32  -0.885     0.7 ...      --        --        --       0
#  15293  7750  29.356  -0.854     1.0 ...      --        --        --       0
#  15295  7750  29.274  -0.875     1.3 ...      --        --        --       0
#  15296  7750  29.305  -0.988     1.8 ...      --        --        --       0
#  15297  7750  29.221  -0.773     2.6 ...      --        --        --       0
#  15303  4100   29.21   0.886     0.6 ...      --        --        --       0
#  15304  4100  29.222   0.905     0.7 ...      --        --        --       0
#  15306  4100   29.14   0.964     1.9 ...      --        --        --       0
#    ...   ...     ...     ...     ... ...     ...       ...       ...     ...
# 184973  4938 349.585   0.525     0.8 ...      --        --        --       0
# 184975  4938 349.504   0.794    22.4 ...      --        --        --       0
# 184976  4938 349.816   0.767    37.5 ...      --        --        --       0
# 184978  4938   349.7   0.584     1.0 ...      --        --        --       0
# 184979  4938 349.756   0.716     8.8 ...      --        --        --       0
# 184980  4938 349.641   0.514     3.1 ...      --        --        --       0
# 184983  4938 349.697   0.596     1.3 ...      --        --        --       0
# 184984  4938 349.602   0.602     0.8 ...      --        --        --       0
# 184985  4938 349.653    0.61     1.1 ...      --        --        --       1
# 196076  7867 352.991   0.463     4.0 ...      --        --        --       0

# %%
if 'Unnamed: 0' in swift.columns:
    del swift['Unnamed: 0']
swift
# Out:
#         ID         RA       DEC  countrates_0.3-10keV(ph.s-1)  \
# 0        0  14.102000 -1.277310                      0.005645
# 1        1  14.079733 -1.249499                      0.004449
# 2        2  14.095850 -1.227643                      0.003901
# 3        3  14.068408 -1.234838                      0.005795
# 4        4  14.070508 -1.221223                      0.005224
# ...    ...        ...       ...                           ...
# 2738  6616  17.460071  0.393572                      0.029060
# 2739  6714  39.237083  0.726716                      0.001072
# 2740  6715  39.230850  0.613294                      0.003750
# 2741  6716  39.304346  0.671991                      0.001367
# 2742  6718  39.137842  0.527952                      0.001279
#
#       countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# 0                                0.00150            4572.8
# 1                                0.00140            4684.2
# 2                                0.00140            4649.6
# 3                                0.00160            4642.0
# 4                                0.00150            4587.3
# ...                                  ...               ...
# 2738                             0.00330            1777.8
# 2739                             0.00046            7910.6
# 2740                             0.00080            7796.8
# 2741                             0.00054            7915.6
# 2742                             0.00053            7826.9
#
#       countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# 0                        0.000868                           0.000600
# 1                        0.000494                           0.000485
# 2                        0.000867                           0.000679
# 3                        0.000446                           0.000460
# 4                        0.002177                           0.000937
# ...                           ...                                ...
# 2738                     0.007267                           0.001650
# 2739                     0.000153                           0.000173
# 2740                     0.001640                           0.000517
# 2741                     0.001367                           0.000540
# 2742                     0.000320                           0.000268
#
#       upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# 0                           -999.0                   0.003040
# 1                           -999.0                   0.001977
# 2                           -999.0                   0.001301
# 3                           -999.0                   0.002674
# 4                           -999.0                   0.001306
# ...                            ...                        ...
# 2738                        -999.0                   0.014530
# 2739                        -999.0                   0.000306
# 2740                        -999.0                   0.001406
# 2741                        -999.0                   0.000513
# 2742                        -999.0                   0.000640
#
#       countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# 0                            0.001125                    -999.000
# 1                            0.000959                    -999.000
# 2                            0.000840                    -999.000
# 3                            0.001100                    -999.000
# 4                            0.000741                    -999.000
# ...                               ...                         ...
# 2738                         0.002348                    -999.000
# 2739                         0.000244                    -999.000
# 2740                         0.000480                    -999.000
# 2741                        -0.539500                       1.652
# 2742                         0.000376                    -999.000
#
#       countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# 0                       0.001737                          0.000853
# 1                       0.001977                          0.000959
# 2                       0.001734                          0.000969
# 3                       0.002674                          0.001100
# 4                       0.001741                          0.000853
# ...                          ...                               ...
# 2738                    0.007267                          0.001650
# 2739                    0.000612                          0.000350
# 2740                    0.000703                          0.000341
# 2741                    0.000256                         -0.539500
# 2742                    0.000320                          0.000268
#
#       upper_limit_2-10keV(ph.s-1)
# 0                        -999.000
# 1                        -999.000
# 2                        -999.000
# 3                        -999.000
# 4                        -999.000
# ...                           ...
# 2738                     -999.000
# 2739                     -999.000
# 2740                     -999.000
# 2741                        1.652
# 2742                     -999.000
#
# [2743 rows x 15 columns]

# %%
# from astropy.coordinates import SkyCoord
# from astropy import units

# swift_coords = SkyCoord(swift.RA, swift.DEC, unit=(units.hourangle,units.degree))
# swift['RA'] = swift_coords.ra.deg
# swift['DEC'] = swift_coords.dec.deg
# swift.head()

# %% [markdown]
# ## xmatch using 'gc' algorithm
#
# Fot a great-circle matching we have to define the search radius.
# I will use LaMassa's mean positional error for that.

# %%
lm_chandra = lm_chandra.to_pandas()

# %%
from astropy import units

rs = lm_chandra['e_Pos'].mean() * units.arcsec

# %%
from xmatch import xmatch

help(xmatch)
# Out:
# Help on function xmatch in module xmatch.xmatchi:
#
# xmatch(catalog_A, catalog_B, columns_A=None, columns_B=None, radius=None, separation_unit='arcsec', method='gc', parallel=False, nprocs=None, snr_column=None)
#     Input:
#      - catalog_A, catalog_B : ~pandas.DataFrame
#              DFs containing (at least) the columns 'ra','dec','id'
#      - columns_A, columns_B : dict mapping 'ra','dec','id' columns
#             In case catalog(s) have different column names for 'ra','dec','id';
#             e.g, {'ra':'RA', 'dec':'Dec', 'id':'ObjID'}
#
#     Output:
#      - matched_catalog : ~pandas.DataFrame

# %%
colsA = dict(ra='RAdeg', dec='DEdeg', id='MSID')
colsB = dict(ra='RA', dec='DEC', id='ID')

xcat = xmatch(lm_chandra, swift, columns_A=colsA, columns_B=colsB, radius=rs)
# Out:
# /home/chbrandt/.conda/envs/xmatch/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/chbrandt/.conda/envs/xmatch/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
xcat
# Out:
#             A                           B                           AB  \
#         RAdeg  DEdeg      MSID         RA       DEC      ID separation
# 0      29.212 -0.760   15288.0        NaN       NaN     NaN        NaN
# 1      29.320 -0.885   15292.0  29.320029 -0.884140  3460.0   3.097780
# 2      29.356 -0.854   15293.0  29.355692 -0.853073  3457.0   3.515782
# 3      29.274 -0.875   15295.0        NaN       NaN     NaN        NaN
# 4      29.305 -0.988   15296.0        NaN       NaN     NaN        NaN
# ...       ...    ...       ...        ...       ...     ...        ...
# 1141  349.641  0.514  184980.0        NaN       NaN     NaN        NaN
# 1142  349.697  0.596  184983.0        NaN       NaN     NaN        NaN
# 1143  349.602  0.602  184984.0        NaN       NaN     NaN        NaN
# 1144  349.653  0.610  184985.0        NaN       NaN     NaN        NaN
# 1145  352.991  0.463  196076.0        NaN       NaN     NaN        NaN
#
#
#      duplicates distances
# 0          None      None
# 1          None      None
# 2          None      None
# 3          None      None
# 4          None      None
# ...         ...       ...
# 1141       None      None
# 1142       None      None
# 1143       None      None
# 1144       None      None
# 1145       None      None
#
# [1146 rows x 9 columns]

# %%
inds = xcat[('AB','separation')].dropna().index
xcat = xcat.iloc[inds]

# %%
s_idx = xcat[('B','ID')].astype(swift['ID'].dtype)
matched_swift_chandra = swift.set_index('ID').loc[s_idx]
matched_swift_chandra
# Out:
#               RA       DEC  countrates_0.3-10keV(ph.s-1)  \
# ID
# 3460   29.320029 -0.884140                      0.003364
# 3457   29.355692 -0.853073                      0.002200
# 1666   29.140300  0.962998                      0.002273
# 146   334.286350  0.454357                      0.001680
# 1082    9.297400 -1.181327                      0.008342
# ...          ...       ...                           ...
# 4256   14.010054  0.578128                      0.002209
# 369   323.389329 -0.972463                      0.006086
# 370   323.425183 -0.968524                      0.000431
# 362   323.328533 -0.943809                      0.001968
# 353   323.353379 -0.908586                      0.000716
#
#       countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# ID
# 3460                             0.00029           50971.4
# 3457                             0.00021           75101.8
# 1666                             0.00057           10091.7
# 146                              0.00070            6393.4
# 1082                             0.00150            4755.4
# ...                                  ...               ...
# 4256                             0.00073            6296.9
# 369                              0.00036           66744.1
# 370                              0.00012           63633.4
# 362                              0.00022           68442.4
# 353                              0.00014           68587.0
#
#       countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# ID
# 3460                     0.000235                           0.000077
# 3457                     0.000159                           0.000057
# 1666                     0.000947                           0.000382
# 146                      0.000336                           0.000325
# 1082                     0.003264                           0.000955
# ...                           ...                                ...
# 4256                     0.000946                           0.000476
# 369                      0.002671                           0.000242
# 370                      0.000144                           0.000067
# 362                      0.000826                           0.000147
# 353                      0.000262                           0.000085
#
#       upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# ID
# 3460                        -999.0                   0.000704
# 3457                        -999.0                   0.000765
# 1666                        -999.0                   0.000568
# 146                         -999.0                   0.001008
# 1082                        -999.0                   0.003627
# ...                            ...                        ...
# 4256                        -999.0                   0.000946
# 369                         -999.0                   0.002203
# 370                         -999.0                   0.000144
# 362                         -999.0                   0.000632
# 353                         -999.0                   0.000239
#
#       countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# ID
# 3460                         0.000133                      -999.0
# 3457                         0.000129                      -999.0
# 1666                         0.000296                      -999.0
# 146                          0.000566                      -999.0
# 1082                         0.000955                      -999.0
# ...                               ...                         ...
# 4256                         0.000476                      -999.0
# 369                          0.000220                      -999.0
# 370                          0.000067                      -999.0
# 362                          0.000128                      -999.0
# 353                          0.000079                      -999.0
#
#       countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# ID
# 3460                    0.002424                          0.000249
# 3457                    0.001275                          0.000161
# 1666                    0.000757                          0.000342
# 146                     0.000336                          0.000325
# 1082                    0.001451                          0.000620
# ...                          ...                               ...
# 4256                    0.000316                          0.000279
# 369                     0.001212                          0.000162
# 370                     0.000144                          0.000067
# 362                     0.000510                          0.000110
# 353                     0.000215                          0.000079
#
#       upper_limit_2-10keV(ph.s-1)
# ID
# 3460                       -999.0
# 3457                       -999.0
# 1666                       -999.0
# 146                        -999.0
# 1082                       -999.0
# ...                           ...
# 4256                       -999.0
# 369                        -999.0
# 370                        -999.0
# 362                        -999.0
# 353                        -999.0
#
# [37 rows x 14 columns]

# %%
matched_swift_chandra.reset_index(inplace=True)

# %%
s_idx = xcat[('A','MSID')].astype(lm_chandra['MSID'].dtype)
matched_lm_chandra = lm_chandra.set_index('MSID').loc[s_idx]
matched_lm_chandra
# Out:
#            ObsID    RAdeg  DEdeg  e_Pos  DistNN     InAO10 InAO13 RemLogNS  \
# MSID
# 15292.0   7750.0   29.320 -0.885    0.7   169.1         no     no      yes
# 15293.0   7750.0   29.356 -0.854    1.0   169.1         no     no       no
# 15306.0   4100.0   29.140  0.964    1.9   363.0         no     no       no
# 28002.0   1694.0  334.287  0.455    2.8    50.2  yes; 1562     no      yes
# 35192.0   2178.0    9.297 -1.182    0.6   142.6         no     no       no
# ...          ...      ...    ...    ...     ...        ...    ...      ...
# 166745.0  7746.0   14.009  0.578    1.3    70.9   yes; 405     no      yes
# 169836.0  8960.0  323.390 -0.973    1.5   131.8  yes; 1306     no      yes
# 169839.0  8960.0  323.426 -0.968    5.9   131.8  yes; 1310     no      yes
# 169842.0  8960.0  323.328 -0.944    4.8   155.5  yes; 1295     no      yes
# 169846.0  8960.0  323.354 -0.909    1.8   150.0  yes; 1300     no      yes
#
#           FSoft  B_FSoft   ...     rH  F250  e_F250  F350  e_F350  F500  \
# MSID                       ...
# 15292.0    0.00     0.37   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 15293.0    1.25     1.48   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 15306.0    3.16     3.66   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 28002.0    3.86     4.03   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 35192.0   12.52    13.12   ...    NaN   NaN     NaN   NaN     NaN   NaN
# ...         ...      ...   ...     ..   ...     ...   ...     ...   ...
# 166745.0   2.94     3.35   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 169836.0  11.00    11.86   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 169839.0   1.31     1.65   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 169842.0   2.69     3.30   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 169846.0   0.95     1.16   ...    NaN   NaN     NaN   NaN     NaN   NaN
#
#           e_F500  XMMAO10CP  XMMAO13CP  CPCoord
# MSID
# 15292.0      NaN        NaN        NaN      0.0
# 15293.0      NaN        NaN        NaN      0.0
# 15306.0      NaN        NaN        NaN      0.0
# 28002.0      NaN        NaN        NaN      0.0
# 35192.0      NaN        NaN        NaN      0.0
# ...          ...        ...        ...      ...
# 166745.0     NaN        NaN        NaN      0.0
# 169836.0     NaN        NaN        NaN      0.0
# 169839.0     NaN        NaN        NaN      0.0
# 169842.0     NaN        NaN        NaN      0.0
# 169846.0     NaN        NaN        NaN      0.0
#
# [37 rows x 120 columns]

# %%
matched_lm_chandra.reset_index(inplace=True)

# %%
len(matched_lm_chandra) == len(matched_swift_chandra)
# Out:
# True

# %%
del lm_chandra, xcat

# %% [markdown]
# ### xmatch LaMassa-xmm10

# %%
lm_xmm10 = lm_xmm10.to_pandas()
lm_xmm10.sample(10)
# Out:
#          Seq        ObsID    RAdeg  DEdeg  e_Pos  DistNN  ExtFlag InXMM  \
# 685    686.0  312190401.0   43.762 -0.028    3.3   144.8      0.0    no
# 2044  2045.0  673002301.0  352.908 -0.520    3.2   204.9      0.0    no
# 2186  2187.0   42341301.0  354.395  0.388    1.5   171.6      0.0    no
# 560    561.0  200480401.0   37.770 -0.794    1.6   279.6      0.0    no
# 616    617.0  111200101.0   40.580 -0.176    2.3    56.4      0.0    no
# 432    433.0  400570301.0   19.621  0.706    0.7   206.7      0.0    no
# 603    604.0  111200101.0   40.545 -0.028    2.6    44.9      0.0    no
# 602    603.0  111200101.0   40.543  0.038    1.8    25.9      0.0    no
# 863    864.0   41170101.0   45.870  0.286    1.2    84.6      0.0    no
# 2150  2151.0  673002301.0  353.410 -0.554    2.3    38.0      0.0    no
#
#         InChandra RemLogNS   ...     rH  F250  e_F250  F350  e_F350  F500  \
# 685            no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 2044           no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 2186           no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 560            no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 616            no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 432            no      yes   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 603   yes; 108752       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 602            no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 863            no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 2150           no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
#
#       e_F500  ChCP  XMMAO13CP  CPCoord
# 685      NaN   NaN        NaN      0.0
# 2044     NaN   NaN        NaN      0.0
# 2186     NaN   NaN        NaN      0.0
# 560      NaN   NaN        NaN      0.0
# 616      NaN   NaN        NaN      0.0
# 432      NaN   NaN        NaN      0.0
# 603      NaN   NaN        NaN      0.0
# 602      NaN   NaN        NaN      0.0
# 863      NaN   NaN        NaN      0.0
# 2150     NaN   NaN        NaN      1.0
#
# [10 rows x 122 columns]

# %%
from astropy import units
rs = lm_xmm10['e_Pos'].mean() * units.arcsec


from xmatch import xmatch
colsA = dict(ra='RAdeg', dec='DEdeg', id='Seq')
colsB = dict(ra='RA', dec='DEC', id='ID')

xcat = xmatch(lm_xmm10, swift, columns_A=colsA, columns_B=colsB, radius=rs)

inds = xcat[('AB','separation')].dropna().index
xcat = xcat.iloc[inds]

s_idx = xcat[('B','ID')].astype(swift['ID'].dtype)
matched_swift_xmm10 = swift.set_index('ID').loc[s_idx]
matched_swift_xmm10.reset_index(inplace=True)

s_idx = xcat[('A','Seq')].astype(lm_xmm10['Seq'].dtype)
matched_lm_xmm10 = lm_xmm10.set_index('Seq').loc[s_idx]
matched_lm_xmm10.reset_index(inplace=True)

len(matched_lm_xmm10) == len(matched_swift_xmm10)
# Out:
# /home/chbrandt/.conda/envs/xmatch/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/chbrandt/.conda/envs/xmatch/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# True

# %%
matched_swift_xmm10
# Out:
#       ID          RA       DEC  countrates_0.3-10keV(ph.s-1)  \
# 0   1491    2.730625  0.996866                      0.001461
# 1   1485    2.936596  0.999114                      0.002169
# 2   4254   14.119817  0.578700                      0.001897
# 3   2085   30.120704  0.479760                      0.008283
# 4    429   40.530454  0.011160                      0.003049
# ..   ...         ...       ...                           ...
# 36   367  323.340871 -0.665681                      0.000516
# 37   351  323.435208 -0.772404                      0.000685
# 38   385  323.524583 -0.944844                      0.001238
# 39  4573  354.548150  0.346332                      0.008421
# 40  4574  354.572679  0.311354                      0.001850
#
#     countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# 0                              0.00051           10375.9
# 1                              0.00055           10142.9
# 2                              0.00067            6222.9
# 3                              0.00110            5700.6
# 4                              0.00036           34723.3
# ..                                 ...               ...
# 36                             0.00013           65050.3
# 37                             0.00013           69857.6
# 38                             0.00021           36895.7
# 39                             0.00160            4857.1
# 40                             0.00084            4843.0
#
#     countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# 0                      0.000852                          -0.509500
# 1                      0.000834                           0.000339
# 2                      0.000813                           0.000434
# 3                      0.003107                           0.000637
# 4                      0.001525                           0.000256
# ..                          ...                                ...
# 36                     0.000172                           0.000074
# 37                     0.000160                           0.000065
# 38                     0.000088                           0.000056
# 39                     0.003661                           0.001084
# 40                     0.000804                          -0.839200
#
#     upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# 0                         0.9441                   0.000418
# 1                      -999.0000                   0.001001
# 2                      -999.0000                   0.000542
# 3                      -999.0000                   0.003107
# 4                      -999.0000                   0.000832
# ..                           ...                        ...
# 36                     -999.0000                   0.000147
# 37                     -999.0000                   0.000205
# 38                     -999.0000                   0.000354
# 39                     -999.0000                   0.002929
# 40                        1.6510                   0.000925
#
#     countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# 0                          0.000275                      -999.0
# 1                          0.000377                      -999.0
# 2                          0.000358                      -999.0
# 3                          0.000637                      -999.0
# 4                          0.000184                      -999.0
# ..                              ...                         ...
# 36                         0.000068                      -999.0
# 37                         0.000073                      -999.0
# 38                         0.000111                      -999.0
# 39                         0.000929                      -999.0
# 40                         0.000576                      -999.0
#
#     countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# 0                     0.001044                          0.000432
# 1                     0.000334                          0.000218
# 2                     0.000542                          0.000358
# 3                     0.002071                          0.000538
# 4                     0.000693                          0.000168
# ..                         ...                               ...
# 36                    0.000197                          0.000080
# 37                    0.000320                          0.000089
# 38                    0.000795                          0.000167
# 39                    0.001831                          0.000774
# 40                    0.000925                          0.000576
#
#     upper_limit_2-10keV(ph.s-1)
# 0                        -999.0
# 1                        -999.0
# 2                        -999.0
# 3                        -999.0
# 4                        -999.0
# ..                          ...
# 36                       -999.0
# 37                       -999.0
# 38                       -999.0
# 39                       -999.0
# 40                       -999.0
#
# [41 rows x 15 columns]

# %%
matched_lm_xmm10
# Out:
#        Seq        ObsID    RAdeg  DEdeg  e_Pos  DistNN  ExtFlag InXMM  \
# 0     79.0  403760301.0    2.731  0.997    0.6    67.0      0.0    no
# 1    129.0  403760301.0    2.937  0.999    1.1   105.6      0.0    no
# 2    417.0  303110401.0   14.120  0.579    0.4   157.1      0.0    no
# 3    521.0  101640201.0   30.121  0.480    0.3    63.3      0.0    no
# 4    600.0  111200101.0   40.530  0.011    1.1    79.7      0.0    no
# ..     ...          ...      ...    ...    ...     ...      ...   ...
# 36  1298.0  304801201.0  323.341 -0.666    1.6    55.0      0.0    no
# 37  1313.0  304801201.0  323.435 -0.772    0.7    39.9      0.0    no
# 38  1322.0  304801201.0  323.525 -0.945    1.2   116.8      0.0    no
# 39  2201.0   42341301.0  354.548  0.346    0.4   157.7      0.0    no
# 40  2202.0   42341301.0  354.573  0.311    1.0    45.4      0.0    no
#
#       InChandra RemLogNS   ...     rH  F250  e_F250  F350  e_F350  F500  \
# 0            no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 1            no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 2   yes; 166741      yes   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 3            no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 4   yes; 108776       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# ..          ...      ...   ...     ..   ...     ...   ...     ...   ...
# 36           no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 37           no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 38           no       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 39  yes; 110514       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
# 40  yes; 110499       no   ...    NaN   NaN     NaN   NaN     NaN   NaN
#
#     e_F500  ChCP  XMMAO13CP  CPCoord
# 0      NaN   NaN        NaN      0.0
# 1      NaN   NaN        NaN      0.0
# 2      NaN     8        NaN      1.0
# 3      NaN   NaN        NaN      0.0
# 4      NaN   NaN        NaN      0.0
# ..     ...   ...        ...      ...
# 36     NaN   NaN        NaN      0.0
# 37     NaN   NaN        NaN      0.0
# 38     NaN   NaN        NaN      0.0
# 39     NaN   NaN        NaN      0.0
# 40     NaN   NaN        NaN      0.0
#
# [41 rows x 122 columns]

# %% [markdown]
# ### xmatch LaMassa-xmm13

# %%
lm_xmm13 = lm_xmm13.to_pandas()
lm_xmm13.sample(10)
# Out:
#          Seq        ObsID   RAdeg  DEdeg  e_Pos  DistNN  ExtFlag InXMM  \
# 1680  4039.0  747420101.0  22.280 -0.081    2.7   207.6      0.0    no
# 778   3137.0  747390101.0  17.308  0.049    2.9   110.8      0.0    no
# 2086  4445.0  747430101.0  25.016  0.033    3.1    52.3      0.0    no
# 1103  3462.0  747400101.0  18.748 -0.099    2.8   104.0      0.0    no
# 1918  4277.0  747430101.0  24.318 -0.313    4.9   116.0      0.0    no
# 1205  3564.0  747400101.0  19.140  0.107    1.8    67.6      0.0    no
# 1937  4296.0  747430101.0  24.396  0.100    2.8   198.4      0.0    no
# 1078  3437.0  747400101.0  18.652  0.291    2.5   213.0      2.0    no
# 2407  4766.0  747440101.0  26.244 -0.099    3.3    64.1      0.0    no
# 1708  4067.0  747420101.0  22.574  0.336    3.9   204.4      0.0    no
#
#      InChandra  FSoft   ...       rH   F250  e_F250   F350  e_F350  F500  \
# 1680        no   2.03   ...     0.33  42.03   10.76  12.68   10.17  10.1
# 778         no   0.34   ...      NaN    NaN     NaN    NaN     NaN   NaN
# 2086        no   0.72   ...      NaN    NaN     NaN    NaN     NaN   NaN
# 1103        no   0.74   ...      NaN    NaN     NaN    NaN     NaN   NaN
# 1918        no   2.91   ...      NaN    NaN     NaN    NaN     NaN   NaN
# 1205        no   3.23   ...      NaN    NaN     NaN    NaN     NaN   NaN
# 1937        no   0.58   ...      NaN    NaN     NaN    NaN     NaN   NaN
# 1078        no   0.93   ...      NaN    NaN     NaN    NaN     NaN   NaN
# 2407        no   1.37   ...      NaN    NaN     NaN    NaN     NaN   NaN
# 1708        no   1.68   ...      NaN    NaN     NaN    NaN     NaN   NaN
#
#       e_F500  XMMAO10CP  ChCP  CPCoord
# 1680   11.39        NaN   NaN      0.0
# 778      NaN        NaN   NaN      0.0
# 2086     NaN        NaN   NaN      1.0
# 1103     NaN        NaN   NaN      0.0
# 1918     NaN        NaN   NaN      0.0
# 1205     NaN        NaN   NaN      0.0
# 1937     NaN        NaN   NaN      0.0
# 1078     NaN        NaN   NaN      0.0
# 2407     NaN        NaN   NaN      0.0
# 1708     NaN        NaN   NaN      0.0
#
# [10 rows x 121 columns]

# %%
from astropy import units
rs = lm_xmm13['e_Pos'].mean() * units.arcsec


from xmatch import xmatch
colsA = dict(ra='RAdeg', dec='DEdeg', id='Seq')
colsB = dict(ra='RA', dec='DEC', id='ID')

xcat = xmatch(lm_xmm13, swift, columns_A=colsA, columns_B=colsB, radius=rs)

inds = xcat[('AB','separation')].dropna().index
xcat = xcat.iloc[inds]

s_idx = xcat[('B','ID')].astype(swift['ID'].dtype)
matched_swift_xmm13 = swift.set_index('ID').loc[s_idx]
matched_swift_xmm13.reset_index(inplace=True)

s_idx = xcat[('A','Seq')].astype(lm_xmm13['Seq'].dtype)
matched_lm_xmm13 = lm_xmm13.set_index('Seq').loc[s_idx]
matched_lm_xmm13.reset_index(inplace=True)

len(matched_lm_xmm13) == len(matched_swift_xmm13)
# Out:
# /home/chbrandt/.conda/envs/xmatch/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/chbrandt/.conda/envs/xmatch/lib/python3.6/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# True

# %%
matched_swift_xmm13
# Out:
#       ID         RA       DEC  countrates_0.3-10keV(ph.s-1)  \
# 0   1562  16.373296 -0.184746                      0.004391
# 1   1565  16.378337 -0.109585                      0.002040
# 2   1564  16.460187 -0.215154                      0.002012
# 3   1317  16.584404 -0.497712                      0.004587
# 4   6271  17.147700 -0.219628                      0.004121
# ..   ...        ...       ...                           ...
# 31  4273  23.587558 -0.608982                      0.005552
# 32  2713  23.685296 -0.583609                      0.012140
# 33  4277  23.737025 -0.460769                      0.001523
# 34    55  24.728296 -0.438786                      0.013190
# 35    54  24.899308 -0.568416                      0.003232
#
#     countrates_error_0.3-10keV(ph.s-1)  exposure_time(s)  \
# 0                              0.00098            5923.2
# 1                              0.00071            6131.5
# 2                              0.00070            6156.7
# 3                              0.00079            9975.1
# 4                              0.00170            1908.1
# ..                                 ...               ...
# 31                             0.00076           13919.9
# 32                             0.00110           13632.0
# 33                             0.00043           14486.7
# 34                             0.00110           14973.5
# 35                             0.00058           16398.1
#
#     countrates_0.3-1keV(ph.s-1)  countrates_error_0.3-1keV(ph.s-1)  \
# 0                      0.001646                           0.000595
# 1                      0.000583                           0.000396
# 2                      0.001118                           0.000550
# 3                      0.001311                           0.000408
# 4                      0.003296                           0.001500
# ..                          ...                                ...
# 31                     0.003193                           0.000567
# 32                     0.004307                           0.000643
# 33                     0.000692                           0.000293
# 34                     0.005048                           0.000660
# 35                     0.001191                           0.000355
#
#     upper_limit_0.3-1keV(ph.s-1)  countrates_1-2keV(ph.s-1)  \
# 0                         -999.0                   0.001372
# 1                         -999.0                   0.000453
# 2                         -999.0                   0.000447
# 3                         -999.0                   0.001638
# 4                         -999.0                   0.000000
# ..                           ...                        ...
# 31                        -999.0                   0.001527
# 32                        -999.0                   0.003915
# 33                        -999.0                   0.000554
# 34                        -999.0                   0.004396
# 35                        -999.0                   0.001191
#
#     countrates_error_1-2keV(ph.s-1)  upper_limit_1-2keV(ph.s-1)  \
# 0                          0.000546                   -999.0000
# 1                         -0.709300                      0.9437
# 2                          0.000335                   -999.0000
# 3                          0.000454                   -999.0000
# 4                         -1.698000                      1.3220
# ..                              ...                         ...
# 31                         0.000392                   -999.0000
# 32                         0.000609                   -999.0000
# 33                         0.000262                   -999.0000
# 34                         0.000613                   -999.0000
# 35                         0.000355                   -999.0000
#
#     countrates_2-10keV(ph.s-1)  countrates_error_2-10keV(ph.s-1)  \
# 0                     0.001372                          0.000546
# 1                     0.001457                          0.000651
# 2                     0.000447                          0.000335
# 3                     0.001638                          0.000454
# 4                     0.000824                          0.000750
# ..                         ...                               ...
# 31                    0.000832                          0.000292
# 32                    0.003915                          0.000609
# 33                    0.000277                          0.000187
# 34                    0.003746                          0.000566
# 35                    0.000851                          0.000300
#
#     upper_limit_2-10keV(ph.s-1)
# 0                        -999.0
# 1                        -999.0
# 2                        -999.0
# 3                        -999.0
# 4                        -999.0
# ..                          ...
# 31                       -999.0
# 32                       -999.0
# 33                       -999.0
# 34                       -999.0
# 35                       -999.0
#
# [36 rows x 15 columns]

# %%
matched_lm_xmm13
# Out:
#        Seq        ObsID   RAdeg  DEdeg  e_Pos  DistNN  ExtFlag InXMM  \
# 0   2893.0  747390101.0  16.373 -0.185    2.3   168.2      0.0    no
# 1   2895.0  747390101.0  16.378 -0.109    1.6   142.2      0.0    no
# 2   2909.0  747390101.0  16.460 -0.215    2.0   153.4      0.0    no
# 3   2936.0  747390101.0  16.584 -0.498    2.5    32.3      0.0    no
# 4   3083.0  747390101.0  17.147 -0.220    3.8   212.0      0.0    no
# ..     ...          ...     ...    ...    ...     ...      ...   ...
# 31  4214.0  747420101.0  23.587 -0.609    3.4   365.3      0.0    no
# 32  4217.0  747420101.0  23.686 -0.584    3.7   365.3      0.0    no
# 33  4224.0  747420101.0  23.737 -0.461    3.7    65.0      0.0    no
# 34  4365.0  747430101.0  24.728 -0.439    0.9   236.7      0.0    no
# 35  4413.0  747430101.0  24.899 -0.569    2.4   223.6      0.0    no
#
#    InChandra  FSoft   ...     rH  F250  e_F250  F350  e_F350  F500  e_F500  \
# 0         no   2.55   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 1         no   1.41   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 2         no   2.50   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 3         no   1.80   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 4         no   0.60   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# ..       ...    ...   ...     ..   ...     ...   ...     ...   ...     ...
# 31        no   3.53   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 32        no   5.70   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 33        no   0.91   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 34        no  12.64   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
# 35        no   4.77   ...    NaN   NaN     NaN   NaN     NaN   NaN     NaN
#
#     XMMAO10CP  ChCP  CPCoord
# 0         NaN   NaN      0.0
# 1         NaN   NaN      0.0
# 2         NaN   NaN      0.0
# 3         NaN   NaN      0.0
# 4         NaN   NaN      1.0
# ..        ...   ...      ...
# 31        NaN   NaN      0.0
# 32        NaN   NaN      0.0
# 33        NaN   NaN      0.0
# 34        NaN   NaN      0.0
# 35        NaN   NaN      0.0
#
# [36 rows x 121 columns]
